# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
k128excel_file = 'result/KAN/kan2-128-1.xlsx'
m128excel_file = 'result/mlp/mlp2-128-1.xlsx'
k64excel_file = 'result/KAN/kan2-64-1.xlsx'
m64excel_file = 'result/mlp/mlp2-64-1.xlsx'
k32excel_file = 'result/KAN/kan2-32-1.xlsx'
m32excel_file = 'result/mlp/mlp2-32-1.xlsx'
k16excel_file = 'result/KAN/kan2-16-1.xlsx'
m16excel_file = 'result/mlp/mlp2-16-1.xlsx'
k8excel_file = 'result/KAN/kan2-8-1.xlsx'
m8excel_file = 'result/mlp/mlp2-8-1.xlsx'
k5excel_file = 'result/KAN/kan2-5-1.xlsx'
m5excel_file = 'result/mlp/mlp2-5-1.xlsx'

time = np.arange(0 ,119)
k5df = pd.read_excel(k5excel_file)
m5df = pd.read_excel(m5excel_file)
k5_True_A = k5df.iloc[1:, 7].values
k5_Predicted_A = k5df.iloc[1:, 8].values
m5_True_A = m5df.iloc[1:, 7].values
m5_Predicted_A = m5df.iloc[1:, 8].values

k8df = pd.read_excel(k8excel_file)
m8df = pd.read_excel(m8excel_file)
k8_True_A = k8df.iloc[1:, 7].values
k8_Predicted_A = k8df.iloc[1:, 8].values
m8_True_A = m8df.iloc[1:, 7].values
m8_Predicted_A = m8df.iloc[1:, 8].values

k16df = pd.read_excel(k16excel_file)
m16df = pd.read_excel(m16excel_file)
k16_True_A = k16df.iloc[1:, 7].values
k16_Predicted_A = k16df.iloc[1:, 8].values
m16_True_A = m16df.iloc[1:, 7].values
m16_Predicted_A = m16df.iloc[1:, 8].values

k32df = pd.read_excel(k32excel_file)
m32df = pd.read_excel(m32excel_file)
k32_True_A = k32df.iloc[1:, 7].values
k32_Predicted_A = k32df.iloc[1:, 8].values
m32_True_A = m32df.iloc[1:, 7].values
m32_Predicted_A = m32df.iloc[1:, 8].values

k64df = pd.read_excel(k64excel_file)
m64df = pd.read_excel(m64excel_file)
k64_True_A = k64df.iloc[1:, 7].values
k64_Predicted_A = k64df.iloc[1:, 8].values
m64_True_A = m64df.iloc[1:, 7].values
m64_Predicted_A = m64df.iloc[1:, 8].values

k128df = pd.read_excel(k128excel_file)
m128df = pd.read_excel(m128excel_file)
k128_True_A = k128df.iloc[1:, 7].values
k128_Predicted_A = k128df.iloc[1:, 8].values
m128_True_A = m128df.iloc[1:, 7].values
m128_Predicted_A = m128df.iloc[1:, 8].values

# %%
plt.figure(figsize=(16, 24))

plt.subplot(6, 2, 1)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m5_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m5_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-5-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 2)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k5_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k5_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-5-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)


plt.subplot(6, 2, 3)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m8_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m8_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-8-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 4)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k8_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k8_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-8-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)


plt.subplot(6, 2, 5)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m16_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m16_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-16-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 6)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k16_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k16_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-16-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)


plt.subplot(6, 2, 7)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m32_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m32_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-32-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 8)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k32_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k32_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-32-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)


plt.subplot(6, 2, 9)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m64_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m64_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-64-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 10)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k64_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k64_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-64-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)


plt.subplot(6, 2, 11)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, m128_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, m128_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('MLP-2-128-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(6, 2, 12)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k128_True_A, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k128_Predicted_A, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Daily New Infection', fontsize=18)
plt.title('KAN-2-128-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)



plt.tight_layout()

plt.savefig('figure/all.tif')

plt.show()

# 获取当前的Axes对象
# ax = plt.gca()
# # 关闭上边框和右边框
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
