# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
k128excel_file = 'result/KAN/kan2-128-1.xlsx'
m128excel_file = 'result/mlp/mlp2-128-1.xlsx'
k32excel_file = 'result/KAN/kan2-32-1.xlsx'
m32excel_file = 'result/mlp/mlp2-32-1.xlsx'
k5excel_file = 'result/KAN/kan2-5-1.xlsx'
m5excel_file = 'result/mlp/mlp2-5-1.xlsx'

time = np.arange(0 ,119)
k5df = pd.read_excel(k5excel_file)
m5df = pd.read_excel(m5excel_file)
k5_True_S = k5df.iloc[1:, 1].values
k5_Predicted_S = k5df.iloc[1:, 2].values
m5_True_S = m5df.iloc[1:, 1].values
m5_Predicted_S = m5df.iloc[1:, 2].values

m5_True_I = m5df.iloc[1:, 3].values
m5_Predicted_I = m5df.iloc[1:, 4].values
k5_True_I = k5df.iloc[1:, 3].values
k5_Predicted_I = k5df.iloc[1:, 4].values

k5_True_R = k5df.iloc[1:, 5].values
k5_Predicted_R = k5df.iloc[1:, 6].values
m5_True_R = m5df.iloc[1:, 5].values
m5_Predicted_R = m5df.iloc[1:, 6].values


k32df = pd.read_excel(k32excel_file)
m32df = pd.read_excel(m32excel_file)
k32_True_S = k32df.iloc[1:, 1].values
k32_Predicted_S = k32df.iloc[1:, 2].values
m32_True_S = m32df.iloc[1:, 1].values
m32_Predicted_S = m32df.iloc[1:, 2].values
k32_True_I = k32df.iloc[1:, 3].values
k32_Predicted_I = k32df.iloc[1:, 4].values
m32_True_I = m32df.iloc[1:, 3].values
m32_Predicted_I = m32df.iloc[1:, 4].values
k32_True_R = k32df.iloc[1:, 5].values
k32_Predicted_R = k32df.iloc[1:, 6].values
m32_True_R = m32df.iloc[1:, 5].values
m32_Predicted_R = m32df.iloc[1:, 6].values

k128df = pd.read_excel(k128excel_file)
m128df = pd.read_excel(m128excel_file)
k128_True_S = k128df.iloc[1:, 1].values
k128_Predicted_S = k128df.iloc[1:, 2].values
m128_True_S = m128df.iloc[1:, 1].values
m128_Predicted_S = m128df.iloc[1:, 2].values
k128_True_I = k128df.iloc[1:, 3].values
k128_Predicted_I = k128df.iloc[1:, 4].values
m128_True_I = m128df.iloc[1:, 3].values
m128_Predicted_I = m128df.iloc[1:, 4].values
k128_True_R = k128df.iloc[1:, 5].values
k128_Predicted_R = k128df.iloc[1:, 6].values
m128_True_R = m128df.iloc[1:, 5].values
m128_Predicted_R = m128df.iloc[1:, 6].values

# %%
plt.figure(figsize=(24, 16))

plt.subplot(3, 3, 1)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k5_True_S, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, k5_Predicted_S, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Susceptible', fontsize=18)
plt.title('KAN-2-5-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 4)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k5_True_I, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k5_Predicted_I, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Infected', fontsize=18)
plt.title('KAN-2-5-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 7)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k5_True_R, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k5_Predicted_R, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Recovered', fontsize=18)
plt.title('KAN-2-5-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 2)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k32_True_S, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, k32_Predicted_S, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Susceptible', fontsize=18)
plt.title('KAN-2-32-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 5)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k32_True_I, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k32_Predicted_I, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Infected', fontsize=18)
plt.title('KAN-2-32-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 8)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k32_True_R, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k32_Predicted_R, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Recovered', fontsize=18)
plt.title('KAN-2-32-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 3)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k128_True_S, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), 
         label='Data') 
plt.plot(time, k128_Predicted_S, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Susceptible', fontsize=18)
plt.title('KAN-2-128-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 6)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k128_True_I, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k128_Predicted_I, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Infected', fontsize=18)
plt.title('KAN-2-128-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)

plt.subplot(3, 3, 9)
plt.axvspan(0, 120, color='gray', alpha=0.1)
plt.plot(time, k128_True_R, 'o', 
         markerfacecolor='none', markersize=4, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255),
         label='Data') 
plt.plot(time, k128_Predicted_R, '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Learned Curve') 
plt.xlabel('Time(days)', fontsize=18)
plt.ylabel('Recovered', fontsize=18)
plt.title('KAN-2-128-1', fontsize=20)
plt.legend()
plt.xlim(-0.5, 120)




plt.tight_layout()

plt.savefig('figure/SIR.tif')

plt.show()
