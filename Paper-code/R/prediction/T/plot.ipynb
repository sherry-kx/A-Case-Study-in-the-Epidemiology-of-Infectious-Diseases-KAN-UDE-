# %% [markdown]
# #### 安装依赖

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### 导入数据

# %%
khexcel_file = 'in_H-t.xlsx'
khdf = pd.read_excel(khexcel_file)
kzexcel_file = 'in_Z-t.xlsx'
kzdf = pd.read_excel(kzexcel_file)
kqexcel_file = 'in_Q-t.xlsx'
kqdf = pd.read_excel(kqexcel_file)

mhexcel_file = 'in_H-tmlp.xlsx'
mhdf = pd.read_excel(mhexcel_file)
mzexcel_file = 'in_Z-tmlp.xlsx'
mzdf = pd.read_excel(mzexcel_file)
mqexcel_file = 'in_Q-tmlp.xlsx'
mqdf = pd.read_excel(mqexcel_file)

# %%
htime = np.arange(0 ,99)
khin_True_A = khdf.iloc[1:, 10].values
khEquation_A = khdf.iloc[1:, 11].values
khin_Predicted_A = khdf.iloc[1:, 12].values
mhin_True_A = mhdf.iloc[1:, 10].values
mhEquation_A = mhdf.iloc[1:, 11].values
mhin_Predicted_A = mhdf.iloc[1:, 12].values




ztime = np.arange(0 ,79)
kzin_True_A = kzdf.iloc[1:, 10].values
kzEquation_A = kzdf.iloc[1:, 11].values
kzin_Predicted_A = kzdf.iloc[1:, 12].values
mzin_True_A = mzdf.iloc[1:, 10].values
mzEquation_A = mzdf.iloc[1:, 11].values
mzin_Predicted_A = mzdf.iloc[1:, 12].values



qtime = np.arange(0 ,79)
kqin_True_A = kqdf.iloc[1:, 10].values
kqEquation_A = kqdf.iloc[1:, 11].values
kqin_Predicted_A = kqdf.iloc[1:, 12].values
mqin_True_A = mqdf.iloc[1:, 10].values
mqEquation_A = mqdf.iloc[1:, 11].values
mqin_Predicted_A = mqdf.iloc[1:, 12].values

# %% [markdown]
# #### 绘图

# %%
# #color=(32/255, 94/255, 167/255)  ###蓝色
# #color=(232/255, 68/255, 69/255)  ###红色
# #color=(246/255, 99/255, 28/255)  ###橙色
# #color=(1/255, 138/255, 103/255)  ###绿色

# %%
last = 60
timeend = 100
plt.figure(figsize=(12, 4))

plt.axvspan(0, 60, color='gray', alpha=0.1)
plt.axvspan(60, 100, color='khaki', alpha=0.3)
plt.text(40, 0.015, 'Train', fontsize=12, ha='center')
plt.text(80, 0.015, 'Prediction', fontsize=12, ha='center')

plt.plot(htime[:last], khin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(htime[:last+1], khEquation_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(htime[:last+1], khin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(htime[:last+1], mhin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Network MLP') 


plt.plot(htime[last:timeend], khin_True_A[last:timeend], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(htime[last:timeend], khEquation_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(htime[last:timeend], khin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(htime[last:timeend], mhin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Network MLP') 

plt.xlabel('Time',fontsize=18)
plt.ylabel('Incidence', fontsize=18)
# plt.title(r"Fraction: $\frac{I}{1+I}$ MLP&KAN",fontsize=20)
plt.title(r'Fuction: $5.0+10e^{(-0.2t)}$ MLP&KAN (H)',fontsize=20)
plt.xlim(-0.5, 100)
# plt.legend(loc='upper left')
plt.legend()
plt.savefig('in_t_H.tif')

# plt.plot(htime[last:timeend], khin_True_A[last:timeend], 'o', color=(246/255, 99/255, 28/255), markersize=8, markeredgecolor='black', label='True data')

# %%
last = 40
timeend = 80
plt.figure(figsize=(12, 4))

plt.axvspan(0, 40, color='gray', alpha=0.1)
plt.axvspan(40, 80, color='khaki', alpha=0.3)
plt.text(20, 0.0175, 'Train', fontsize=12, ha='center')
plt.text(60, 0.0175, 'Prediction', fontsize=12, ha='center')

plt.plot(ztime[:last], kzin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(ztime[:last+1], kzin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(ztime[:last+1], kzin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(ztime[:last+1], mzin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Network MLP') 


plt.plot(ztime[last:timeend], kzin_True_A[last:timeend], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(ztime[last:timeend], kzin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(ztime[last:timeend], kzin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(ztime[last:timeend], mzin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Network MLP') 

plt.xlabel('Time',fontsize=18)
plt.ylabel('Incidence', fontsize=18)
# plt.title(r"Fraction: $\frac{I}{1+I}$ MLP&KAN",fontsize=20)
plt.title(r'Fuction: $5.0+10e^{(-0.2t)}$ MLP&KAN (Z)',fontsize=20)
plt.xlim(-0.5, 80)
plt.legend()
plt.savefig('in_t_Z.tif')

# %%
last = 30
timeend = 80
plt.figure(figsize=(12, 4))

plt.axvspan(0, 30, color='gray', alpha=0.1)
plt.axvspan(30, 80, color='khaki', alpha=0.3)
plt.text(15, 0.0175, 'Train', fontsize=12, ha='center')
plt.text(60, 0.0175, 'Prediction', fontsize=12, ha='center')

plt.plot(qtime[:last], kqin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(qtime[:last+1], kqin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(qtime[:last+1], kqin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(qtime[:last+1], mqin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Network MLP') 


plt.plot(qtime[last:timeend], kqin_True_A[last:timeend], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='True data') 
plt.plot(qtime[last:timeend], kqin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Mechanism model')
plt.plot(qtime[last:timeend], kqin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Network KAN') 
plt.plot(qtime[last:timeend], mqin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Network MLP') 

plt.xlabel('Time',fontsize=18)
plt.ylabel('Incidence', fontsize=18)
# plt.title(r"Fraction: $\frac{I}{1+I}$ MLP&KAN",fontsize=20)
plt.title(r'Fuction: $5.0+10e^{(-0.2t)}$ MLP&KAN (Q)',fontsize=20)
plt.xlim(-0.5, 80)
plt.legend()
plt.savefig('in_t_Q.tif')
