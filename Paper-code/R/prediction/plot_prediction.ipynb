# %% [markdown]
# #### 安装依赖

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### 导入数据

# %%
ikhexcel_file = 'SI/result/in_YC_R_H.xlsx'
ikhdf = pd.read_excel(ikhexcel_file)
ikzexcel_file = 'SI/result/in_YC_R_Z.xlsx'
ikzdf = pd.read_excel(ikzexcel_file)
ikqexcel_file = 'SI/result/in_YC_R_Q.xlsx'
ikqdf = pd.read_excel(ikqexcel_file)

imhexcel_file = 'SI/result/in_YC_R_H-mlp.xlsx'
imhdf = pd.read_excel(imhexcel_file)
imzexcel_file = 'SI/result/in_YC_R_Z-mlp.xlsx'
imzdf = pd.read_excel(imzexcel_file)
imqexcel_file = 'SI/result/in_YC_R_Q-mlp.xlsx'
imqdf = pd.read_excel(imqexcel_file)

# %%
ekhexcel_file = 'E/result/in_H-E-a-0.5.xlsx'
ekhdf = pd.read_excel(ekhexcel_file)
ekzexcel_file = 'E/result/in_Z-E-a-0.5.xlsx'
ekzdf = pd.read_excel(ekzexcel_file)
ekqexcel_file = 'E/result/in_Q-E-a-0.5.xlsx'
ekqdf = pd.read_excel(ekqexcel_file)

emhexcel_file = 'E/result/in_H-E-a-0.5mlp.xlsx'
emhdf = pd.read_excel(emhexcel_file)
emzexcel_file = 'E/result/in_Z-E-a-0.5mlp.xlsx'
emzdf = pd.read_excel(emzexcel_file)
emqexcel_file = 'E/result/in_Q-E-a-0.5mlp.xlsx'
emqdf = pd.read_excel(emqexcel_file)

# %%
fkhexcel_file = 'fenshi/result/in_H-fenshi-a-1.xlsx'
fkhdf = pd.read_excel(fkhexcel_file)
fkzexcel_file = 'fenshi/result/in_Z-fenshi-a-1.xlsx'
fkzdf = pd.read_excel(fkzexcel_file)
fkqexcel_file = 'fenshi/result/in_Q-fenshi-a-1.xlsx'
fkqdf = pd.read_excel(fkqexcel_file)

fmhexcel_file = 'fenshi/result/in_H-fenshi-a-1mlp.xlsx'
fmhdf = pd.read_excel(fmhexcel_file)
fmzexcel_file = 'fenshi/result/in_Z-fenshi-a-1mlp.xlsx'
fmzdf = pd.read_excel(fmzexcel_file)
fmqexcel_file = 'fenshi/result/in_Q-fenshi-a-1mlp.xlsx'
fmqdf = pd.read_excel(fmqexcel_file)

# %%
tkhexcel_file = 'T/result/in_H-t.xlsx'
tkhdf = pd.read_excel(tkhexcel_file)
tkzexcel_file = 'T/result/in_Z-t.xlsx'
tkzdf = pd.read_excel(tkzexcel_file)
tkqexcel_file = 'T/result/in_Q-t.xlsx'
tkqdf = pd.read_excel(tkqexcel_file)

tmhexcel_file = 'T/result/in_H-tmlp.xlsx'
tmhdf = pd.read_excel(tmhexcel_file)
tmzexcel_file = 'T/result/in_Z-tmlp.xlsx'
tmzdf = pd.read_excel(tmzexcel_file)
tmqexcel_file = 'T/result/in_Q-tmlp.xlsx'
tmqdf = pd.read_excel(tmqexcel_file)

# %%
ihtime = np.arange(0 ,139)
ikhin_True_A = ikhdf.iloc[1:, 5].values
ikhin_Predicted_A = ikhdf.iloc[1:, 6].values
imhin_True_A = imhdf.iloc[1:, 5].values
imhin_Predicted_A = imhdf.iloc[1:, 6].values


iztime = np.arange(0 ,119)
ikzin_True_A = ikzdf.iloc[1:, 5].values
ikzin_Predicted_A = ikzdf.iloc[1:, 6].values
imzin_True_A = imzdf.iloc[1:, 5].values
imzin_Predicted_A = imzdf.iloc[1:, 6].values



iqtime = np.arange(0 ,99)
ikqin_True_A = ikqdf.iloc[1:, 5].values
ikqin_Predicted_A = ikqdf.iloc[1:, 6].values
imqin_True_A = imqdf.iloc[1:, 5].values
imqin_Predicted_A = imqdf.iloc[1:, 6].values

# %%
ehtime = np.arange(0 ,139)
ekhin_True_A = ekhdf.iloc[1:, 7].values
ekhEquation_A = ekhdf.iloc[1:, 8].values
ekhin_Predicted_A = ekhdf.iloc[1:, 9].values
emhin_True_A = emhdf.iloc[1:, 7].values
emhEquation_A = emhdf.iloc[1:, 8].values
emhin_Predicted_A = emhdf.iloc[1:, 9].values



eztime = np.arange(0 ,119)
ekzin_True_A = ekzdf.iloc[1:, 7].values
ekzEquation_A = ekzdf.iloc[1:, 8].values
ekzin_Predicted_A = ekzdf.iloc[1:, 9].values
emzin_True_A = emzdf.iloc[1:, 7].values
emzEquation_A = emzdf.iloc[1:, 8].values
emzin_Predicted_A = emzdf.iloc[1:, 9].values



eqtime = np.arange(0 ,99)
ekqin_True_A = ekqdf.iloc[1:, 7].values
ekqEquation_A = ekqdf.iloc[1:, 8].values
ekqin_Predicted_A = ekqdf.iloc[1:, 9].values
emqin_True_A = emqdf.iloc[1:, 7].values
emqEquation_A = emqdf.iloc[1:, 8].values
emqin_Predicted_A = emqdf.iloc[1:, 9].values

# %%
fhtime = np.arange(0 ,139)
fkhin_True_A = fkhdf.iloc[1:, 7].values
fkhEquation_A = fkhdf.iloc[1:, 8].values
fkhin_Predicted_A = fkhdf.iloc[1:, 9].values
fmhin_True_A = fmhdf.iloc[1:, 7].values
fmhEquation_A = fmhdf.iloc[1:, 8].values
fmhin_Predicted_A = fmhdf.iloc[1:, 9].values

fztime = np.arange(0 ,119)
fkzin_True_A = fkzdf.iloc[1:, 7].values
fkzEquation_A = fkzdf.iloc[1:, 8].values
fkzin_Predicted_A = fkzdf.iloc[1:, 9].values
fmzin_True_A = fmzdf.iloc[1:, 7].values
fmzEquation_A = fmzdf.iloc[1:, 8].values
fmzin_Predicted_A = fmzdf.iloc[1:, 9].values


fqtime = np.arange(0 ,99)
fkqin_True_A = fkqdf.iloc[1:, 7].values
fkqEquation_A = fkqdf.iloc[1:, 8].values
fkqin_Predicted_A = fkqdf.iloc[1:, 9].values
fmqin_True_A = fmqdf.iloc[1:, 7].values
fmqEquation_A = fmqdf.iloc[1:, 8].values
fmqin_Predicted_A = fmqdf.iloc[1:, 9].values

# %%
thtime = np.arange(0 ,139)
tkhin_True_A = tkhdf.iloc[1:, 7].values
tkhEquation_A = tkhdf.iloc[1:, 8].values
tkhin_Predicted_A = tkhdf.iloc[1:, 9].values
tmhin_True_A = tmhdf.iloc[1:, 7].values
tmhEquation_A = tmhdf.iloc[1:, 8].values
tmhin_Predicted_A = tmhdf.iloc[1:, 9].values

tztime = np.arange(0 ,119)
tkzin_True_A = tkzdf.iloc[1:, 7].values
tkzEquation_A = tkzdf.iloc[1:, 8].values
tkzin_Predicted_A = tkzdf.iloc[1:, 9].values
tmzin_True_A = tmzdf.iloc[1:, 7].values
tmzEquation_A = tmzdf.iloc[1:, 8].values
tmzin_Predicted_A = tmzdf.iloc[1:, 9].values

tqtime = np.arange(0 ,99)
tkqin_True_A = tkqdf.iloc[1:, 7].values
tkqEquation_A = tkqdf.iloc[1:, 8].values
tkqin_Predicted_A = tkqdf.iloc[1:, 9].values
tmqin_True_A = tmqdf.iloc[1:, 7].values
tmqEquation_A = tmqdf.iloc[1:, 8].values
tmqin_Predicted_A = tmqdf.iloc[1:, 9].values

# %% [markdown]
# #### 绘图

# %%
# #color=(32/255, 94/255, 167/255)  ###蓝色
# #color=(232/255, 68/255, 69/255)  ###红色
# #color=(246/255, 99/255, 28/255)  ###橙色
# #color=(1/255, 138/255, 103/255)  ###绿色

# %%
last = 100
timeend = 139
fig, axs = plt.subplots(2, 2, figsize=(16, 9))

plt.subplot(2, 2, 1)
plt.axvspan(0, 80, color='gray', alpha=0.1)
plt.axvspan(80, 120, color='khaki', alpha=0.3)
plt.text(60, 0.009, 'Training', fontsize=12, ha='center')
plt.text(100, 0.009, 'Prediction', fontsize=12, ha='center')

plt.plot(ihtime[:last], ikhin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(ihtime[last:timeend], ikhin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(ihtime[:last+1], ikhin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(ihtime[:last+1], ikhin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(ihtime[:last+1], imhin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(ihtime[last:timeend], ikhin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(ihtime[last:timeend], ikhin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(ihtime[last:timeend], imhin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=16)
plt.ylabel('Daily Reported Cases', fontsize=16)
plt.title(r'Mass action $\beta$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')



plt.subplot(2, 2, 2)
plt.axvspan(0, 80, color='gray', alpha=0.1)
plt.axvspan(80, 120, color='khaki', alpha=0.3)
plt.text(62, 0.008, 'Training', fontsize=12, ha='center')
plt.text(102, 0.008, 'Prediction', fontsize=12, ha='center')

plt.plot(ehtime[:last], ekhin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(ehtime[last:timeend], ekhin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(ehtime[:last+1], ekhin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(ehtime[:last+1], ekhin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(ehtime[:last+1], emhin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(ehtime[last:timeend], ekhin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(ehtime[last:timeend], ekhin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(ehtime[last:timeend], emhin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with media effects $\beta$$e^{- \alpha I}$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')



plt.subplot(2, 2, 3)
plt.axvspan(0, 80, color='gray', alpha=0.1)
plt.axvspan(80, 120, color='khaki', alpha=0.3)
plt.text(60, 0.007, 'Training', fontsize=12, ha='center')
plt.text(100, 0.007, 'Prediction', fontsize=12, ha='center')

plt.plot(fhtime[:last], fkhin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(fhtime[last:timeend], fkhin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(fhtime[:last+1], fkhin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(fhtime[:last+1], fkhin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(fhtime[:last+1], fmhin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(fhtime[last:timeend], fkhin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(fhtime[last:timeend], fkhin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(fhtime[last:timeend], fmhin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Nonlinear saturated incidence rate $\beta \frac{S I^l}{1 + \alpha I^h}$',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')


plt.subplot(2, 2, 4)
plt.axvspan(0, 80, color='gray', alpha=0.1)
plt.axvspan(80, 120, color='khaki', alpha=0.3)
plt.text(60, 0.008, 'Training', fontsize=12, ha='center')
plt.text(100, 0.008, 'Prediction', fontsize=12, ha='center')

plt.plot(thtime[:last], tkhin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(thtime[last:timeend], tkhin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255), markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(thtime[:last+1], tkhin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(thtime[:last+1], tkhin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(thtime[:last+1], tmhin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(thtime[last:timeend], tkhin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(thtime[last:timeend], tkhin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(thtime[last:timeend], tmhin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with control effects $\beta\left(\left(c_{0}-c_{b}\right) e^{-r t}+c_{b}\right)$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')

# 子图的标签列表
labels = ['(A)', '(B)', '(C)', '(D)']

# 为每个子图添加标签
for i, ax in enumerate(axs.flat):
    ax.text(-0.1, 1.1, labels[i], transform=ax.transAxes, 
            fontsize=16, fontweight='normal', va='top', ha='right')

plt.tight_layout()
plt.savefig('in_YC_A_H.tif')
# plt.plot(htime[last:timeend], khin_True_A[last:timeend], 'o', color=(246/255, 99/255, 28/255), markersize=8, markeredgecolor='black', label='True data')

# %%
last = 80
timeend = 119
fig, axs = plt.subplots(2, 2, figsize=(16, 9))

plt.subplot(2, 2, 1)
plt.axvspan(0, 60, color='gray', alpha=0.1)
plt.axvspan(60, 120, color='khaki', alpha=0.3)
plt.text(38, 0.009, 'Training', fontsize=12, ha='center')
plt.text(100, 0.009, 'Prediction', fontsize=12, ha='center')

plt.plot(iztime[:last], ikzin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data')
plt.plot(iztime[last:timeend], ikzin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data')  
plt.plot(iztime[:last+1], ikzin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(iztime[:last+1], ikzin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(iztime[:last+1], imzin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(iztime[last:timeend], ikzin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(iztime[last:timeend], ikzin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(iztime[last:timeend], imzin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=16)
plt.ylabel('Daily Reported Cases', fontsize=16)
plt.title(r'Mass action $\beta$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')



plt.subplot(2, 2, 2)
plt.axvspan(0, 60, color='gray', alpha=0.1)
plt.axvspan(60, 120, color='khaki', alpha=0.3)
plt.text(40, 0.009, 'Training', fontsize=12, ha='center')
plt.text(105, 0.009, 'Prediction', fontsize=12, ha='center')

plt.plot(eztime[:last], ekzin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data')
plt.plot(eztime[last:timeend], ekzin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data')  
plt.plot(eztime[:last+1], ekzin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(eztime[:last+1], ekzin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(eztime[:last+1], emzin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(eztime[last:timeend], ekzin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(eztime[last:timeend], ekzin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(eztime[last:timeend], emzin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with media effects $\beta$$e^{- \alpha I}$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')



plt.subplot(2, 2, 3)
plt.axvspan(0, 60, color='gray', alpha=0.1)
plt.axvspan(60, 120, color='khaki', alpha=0.3)
plt.text(40, 0.012, 'Training', fontsize=12, ha='center')
plt.text(100, 0.012, 'Prediction', fontsize=12, ha='center')

plt.plot(fztime[:last], fkzin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data')
plt.plot(fztime[last:timeend], fkzin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data')  
plt.plot(fztime[:last+1], fkzin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(fztime[:last+1], fkzin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(fztime[:last+1], fmzin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(fztime[last:timeend], fkzin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(fztime[last:timeend], fkzin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(fztime[last:timeend], fmzin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Nonlinear saturated incidence rate $\beta \frac{S I^l}{1 + \alpha I^h}$',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')


plt.subplot(2, 2, 4)
plt.axvspan(0, 60, color='gray', alpha=0.1)
plt.axvspan(60, 120, color='khaki', alpha=0.3)
plt.text(52, 0.005, 'Training', fontsize=12, ha='center')
plt.text(90, 0.005, 'Prediction', fontsize=12, ha='center')

plt.plot(tztime[:last], tkzin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data')
plt.plot(tztime[last:timeend], tkzin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data')  
plt.plot(tztime[:last+1], tkzin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(tztime[:last+1], tkzin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(tztime[:last+1], tmzin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(tztime[last:timeend], tkzin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(tztime[last:timeend], tkzin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(tztime[last:timeend], tmzin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with control effects $\beta\left(\left(c_{0}-c_{b}\right) e^{-r t}+c_{b}\right)$SI',fontsize=16)
plt.xlim(-0.5, 120)
plt.legend(loc='upper left')


# 子图的标签列表
labels = ['(A)', '(B)', '(C)', '(D)']

# 为每个子图添加标签
for i, ax in enumerate(axs.flat):
    ax.text(-0.1, 1.1, labels[i], transform=ax.transAxes, 
            fontsize=16, fontweight='normal', va='top', ha='right')

plt.tight_layout()
plt.savefig('in_YC_A_Z.tif')

# %%
last = 60
timeend = 119
fig, axs = plt.subplots(2, 2, figsize=(16, 9))

plt.subplot(2, 2, 1)
plt.axvspan(0, 40, color='gray', alpha=0.1)
plt.axvspan(40, 80, color='khaki', alpha=0.3)
plt.text(30, 0.008, 'Training', fontsize=12, ha='center')
plt.text(68, 0.008, 'Prediction', fontsize=12, ha='center')

plt.plot(iqtime[:last], ikqin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(iqtime[last:timeend], ikqin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(iqtime[:last+1], ikqin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(iqtime[:last+1], ikqin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(iqtime[:last+1], imqin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(iqtime[last:timeend], ikqin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(iqtime[last:timeend], ikqin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(iqtime[last:timeend], imqin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=16)
plt.ylabel('Daily Reported Cases', fontsize=16)
plt.title(r'Mass action $\beta$SI',fontsize=16)
plt.xlim(-0.5, 80)
plt.legend(loc='upper left')



plt.subplot(2, 2, 2)
plt.axvspan(0, 40, color='gray', alpha=0.1)
plt.axvspan(40, 80, color='khaki', alpha=0.3)
plt.text(30, 0.009, 'Training', fontsize=12, ha='center')
plt.text(70, 0.009, 'Prediction', fontsize=12, ha='center')

plt.plot(eqtime[:last], ekqin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(eqtime[last:timeend], ekqin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(eqtime[:last+1], ekqin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(eqtime[:last+1], ekqin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(eqtime[:last+1], emqin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(eqtime[last:timeend], ekqin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(eqtime[last:timeend], ekqin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(eqtime[last:timeend], emqin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with media effects $\beta$$e^{- \alpha I}$SI',fontsize=16)
plt.xlim(-0.5, 80)
plt.legend(loc='upper left')



plt.subplot(2, 2, 3)
plt.axvspan(0, 40, color='gray', alpha=0.1)
plt.axvspan(40, 80, color='khaki', alpha=0.3)
plt.text(30, 0.007, 'Training', fontsize=12, ha='center')
plt.text(70, 0.007, 'Prediction', fontsize=12, ha='center')

plt.plot(fqtime[:last], fkqin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(fqtime[last:timeend], fkqin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(fqtime[:last+1], fkqin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(fqtime[:last+1], fkqin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(fqtime[:last+1], fmqin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(fqtime[last:timeend], fkqin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(fqtime[last:timeend], fkqin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(fqtime[last:timeend], fmqin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Nonlinear saturated incidence rate $\beta \frac{S I^l}{1 + \alpha I^h}$',fontsize=16)
plt.xlim(-0.5, 80)
plt.legend(loc='upper left')


plt.subplot(2, 2, 4)
plt.axvspan(0, 40, color='gray', alpha=0.1)
plt.axvspan(40, 80, color='khaki', alpha=0.3)
plt.text(30, 0.006, 'Training', fontsize=12, ha='center')
plt.text(70, 0.006, 'Prediction', fontsize=12, ha='center')

plt.plot(tqtime[:last], tkqin_True_A[:last], 'o', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=6, markeredgewidth=2,
         markeredgecolor=(57/255, 127/255, 199/255), label='Training Data') 
plt.plot(tqtime[last:timeend], tkqin_True_A[last:timeend], '*', 
         color=(57/255, 127/255, 199/255),markerfacecolor='none', markersize=8, markeredgewidth=1,
         markeredgecolor=(57/255, 127/255, 199/255), label='Validadtion Data') 
plt.plot(tqtime[:last+1], tkqin_True_A[:last+1], '-', color=(232/255, 68/255, 69/255), linewidth=2, label='RMM')
plt.plot(tqtime[:last+1], tkqin_Predicted_A[:last+1], '-', color=(1/255, 138/255, 103/255), linewidth=2, label='Learned(KAN-UDE)') 
plt.plot(tqtime[:last+1], tmqin_Predicted_A[:last+1], '-', color='black', linewidth=2, label='Learned(MLP)') 
plt.plot(tqtime[last:timeend], tkqin_True_A[last:timeend], '--', color=(232/255, 68/255, 69/255), linewidth=2, label='Prediction(RMM)')
plt.plot(tqtime[last:timeend], tkqin_Predicted_A[last:timeend], '--', color=(1/255, 138/255, 103/255), linewidth=2, label='Prediction(KAN-UDE)') 
plt.plot(tqtime[last:timeend], tmqin_Predicted_A[last:timeend], '--', color='black', linewidth=2, label='Prediction(MLP-UDE)') 

plt.xlabel('Time(days)',fontsize=14)
plt.ylabel('Daily Reported Cases', fontsize=18)
plt.title(r'Incidence rate with control effects $\beta\left(\left(c_{0}-c_{b}\right) e^{-r t}+c_{b}\right)$SI',fontsize=16)
plt.xlim(-0.5, 80)
plt.legend(loc='upper left')

# 子图的标签列表
labels = ['(A)', '(B)', '(C)', '(D)']

# 为每个子图添加标签
for i, ax in enumerate(axs.flat):
    ax.text(-0.1, 1.1, labels[i], transform=ax.transAxes, 
            fontsize=16, fontweight='normal', va='top', ha='right')

plt.tight_layout()
plt.savefig('in_YC_A_Q.tif')
